# %% [markdown]
# <a href="https://colab.research.google.com/github/vidya-srd17/vidya-srd17/blob/main/vidya%20python%20theory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1="good morning"
print(str1)
# Out:
# good morning

# %%
str1="hello"
str2=" there"
bob=str1 + str2
print(bob)
# Out:
# hello there

# %%
str3='123'
x=int(str3)+1
print(x)
# Out:
# 124

# %%
str1="123"
str3="1"
print(str1+str3)
# Out:
# 1231

# %%
fruit="banana"
for i in range(len(fruit)):
       print(i)
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
str ="fruit"
for i in range(-1 ,-len(str) - 1,-1):
    print(i,str[i])
# Out:
# -1 t
# -2 i
# -3 u
# -4 r
# -5 f

# %%
str1="hello"
str2="all"
print(str1*3) #print repetation
# Out:
# hellohellohello
